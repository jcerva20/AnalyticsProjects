# %% [markdown]
# # <h1 align = "center">Lego Set </h1>
# ***

# %% [markdown]
# <h3><strong>Scope of the Project:</strong></h3>
# <ul>
#     <li>Demonstrate ability in loading files and merging them together</li>
#     <li>Demonstrating ability in Cleaning the dataset and validating the data as well</li>
#     <li>Querying/Manipulating the dataset to answer questions</li>
#     <li>Visualization done using Power Bi (Check Power Bi tab)</li>
# </ul>

# %% [markdown]
# ### __Info regarding the Data Set__
# __datasets/lego_sets.csv__
# - set_num: A code that is unique to each set in the dataset. This column is critical, and a missing value indicates the set is a duplicate or invalid!
# - set_name: A name for every set in the dataset (note that this can be the same for different sets).
# - year: The date the set was released.
# - num_parts: The number of parts contained in the set. This column is not central to our analyses, so missing values are acceptable.
# - theme_name: The name of the sub-theme of the set.
# - parent_theme: The name of the parent theme the set belongs to. Matches the `name` column of the `parent_themes` csv file.<br><br>
# __datasets/parent_themes.csv__
#
#
# - id: A code that is unique to every theme.
# - name: The name of the parent theme.
# - is_licensed: A Boolean column specifying whether the theme is a licensed theme.
# ***

# %% [markdown]
# ### Q1:  __What Percentage of all licensed sets ever released were Star Wars themed__ <br>

# %%
import pandas as pd

# %% [markdown]
# Loading Dataset:

# %%
lego_set_raw = pd.read_csv(r"C:\Users\alexc\OneDrive\Documents\Lego_Data_Analysis\Lego_Data\lego_sets.csv")
lego_set_raw.head(10)
# Out:
#   set_num                          name  year  num_parts    theme_name  \
# 0    00-1               Weetabix Castle  1970      471.0        Castle
# 1  0011-2             Town Mini-Figures  1978        NaN  Supplemental
# 2  0011-3    Castle 2 for 1 Bonus Offer  1987        NaN  Lion Knights
# 3  0012-1            Space Mini-Figures  1979       12.0  Supplemental
# 4  0013-1            Space Mini-Figures  1979       12.0  Supplemental
# 5  0014-1            Space Mini-Figures  1979       12.0  Supplemental
# 6  0015-1            Space Mini-Figures  1979        NaN  Supplemental
# 7  0016-1           Castle Mini Figures  1978        NaN        Castle
# 8    00-2  Weetabix Promotional House 1  1976        NaN      Building
# 9    00-3  Weetabix Promotional House 2  1976        NaN      Building
#
#   parent_theme
# 0     Legoland
# 1         Town
# 2       Castle
# 3        Space
# 4        Space
# 5        Space
# 6        Space
# 7       Castle
# 8     Legoland
# 9     Legoland

# %% [markdown]
# Loading Dataset 2:

# %%
parent_theme_raw = pd.read_csv(r"C:\Users\alexc\OneDrive\Documents\Lego_Data_Analysis\Lego_Data\parent_themes.csv")
parent_theme_raw.head()
# Out:
#     id     name  is_licensed
# 0    1  Technic        False
# 1   22  Creator        False
# 2   50     Town        False
# 3  112   Racers        False
# 4  126    Space        False

# %% [markdown]
# Checking to see if the ID verification set contains any duplicate values, if it does then those duplicates will have to be removed.<br>They will have to be removed because this Dataset will be used as a Primary key essentially so there cannot be any duplicates.

# %%
parent_theme_raw.duplicated().sum()
# Out:
# 0

# %%
parent_theme_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 111 entries, 0 to 110
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           111 non-null    int64
#  1   name         111 non-null    object
#  2   is_licensed  111 non-null    bool
# dtypes: bool(1), int64(1), object(1)
# memory usage: 2.0+ KB

# %% [markdown]
# Checking to see if there is any null values within the Dataset:

# %%
parent_theme_raw["name"].isnull().sum()
# Out:
# 0

# %% [markdown]
# Changing the column name to parent_theme, so we can merge both this Dataset and the lego Dataset on the same column:

# %%
parent_theme_raw.rename(columns= {"name":"parent_theme"},inplace=True)
parent_theme_raw.head()
# Out:
#     id parent_theme  is_licensed
# 0    1      Technic        False
# 1   22      Creator        False
# 2   50         Town        False
# 3  112       Racers        False
# 4  126        Space        False

# %%
parent_theme_raw[parent_theme_raw["is_licensed"]== True].count()
# Out:
# id              22
# parent_theme    22
# is_licensed     22
# dtype: int64

# %% [markdown]
# Since, there was no issues within the Parent theme Dataset, then its time to Merge both the parent theme and Lego Dataset together using a left join. <br>
# A left join is basically a VLookup or XLookup in Excel terms.<br><br>
# We are joining on the "parent_theme" column:

# %%
merged_data = pd.merge(left=lego_set_raw,right=parent_theme_raw,how="left",left_on=["parent_theme"],right_on=["parent_theme"])
merged_data.head(50)
# Out:
#     set_num                                           name  year  num_parts  \
# 0      00-1                                Weetabix Castle  1970      471.0
# 1    0011-2                              Town Mini-Figures  1978        NaN
# 2    0011-3                     Castle 2 for 1 Bonus Offer  1987        NaN
# 3    0012-1                             Space Mini-Figures  1979       12.0
# 4    0013-1                             Space Mini-Figures  1979       12.0
# 5    0014-1                             Space Mini-Figures  1979       12.0
# 6    0015-1                             Space Mini-Figures  1979        NaN
# 7    0016-1                            Castle Mini Figures  1978        NaN
# 8      00-2                   Weetabix Promotional House 1  1976        NaN
# 9      00-3                   Weetabix Promotional House 2  1976        NaN
# 10     00-4                  Weetabix Promotional Windmill  1976      126.0
# 11    005-1                Basic Building Set in Cardboard  1965       35.0
# 12     00-6                                  Special Offer  1985        3.0
# 13     00-7              Weetabix Promotional Lego Village  1976        NaN
# 14    010-1                Basic Building Set in Cardboard  1965       57.0
# 15    010-3                             Basic Building Set  1968       77.0
# 16    011-1                             Basic Building Set  1968      145.0
# 17    022-1                             Basic Building Set  1968      110.0
# 18  03093-1                The Race to Build It Board Game  1999        NaN
# 19    033-2                             Basic Building Set  1968        NaN
# 20    044-1                             Basic Building Set  1968        NaN
# 21    055-2                             Basic Building Set  1968        NaN
# 22    066-1                             Basic Building Set  1968        NaN
# 23    080-1                  Basic Building Set with Train  1967      710.0
# 24    088-1                                      Super Set  1969      615.0
# 25  10000-1                                    Guarded Inn  2001      256.0
# 26  10001-1                                     Metroliner  2001        NaN
# 27  10002-1                              Railroad Club Car  2001      272.0
# 28  10003-1                          1 x 2 Sand Red Bricks  2001      100.0
# 29  10004-1                          2 x 2 Sand Red Bricks  2001      100.0
# 30  10005-1                          2 x 4 Sand Red Bricks  2001       50.0
# 31  10006-1                          1 x 6 Sand Red Bricks  2001       50.0
# 32  10007-1    2 x 4 Sand Red Ridge Roof Tiles Steep Slope  2001       25.0
# 33  10008-1                       2 x 4 Roof Tile Sand Red  2001       50.0
# 34  10009-1                           Assorted Blue Bricks  2001       62.0
# 35    100-1         4.5V Motor with Wheels (Small Version)  1966       16.0
# 36  10010-1                         Assorted Yellow Bricks  2003       63.0
# 37  10011-1                           Assorted Blue Plates  2001       42.0
# 38  10012-1                         Assorted Yellow Plates  2001        NaN
# 39  10013-1                             Open Freight Wagon  2001        NaN
# 40  10014-1                                        Caboose  2001      170.0
# 41  10015-1                                Passenger Wagon  2001      194.0
# 42  10016-1                                         Tanker  2001      128.0
# 43  10017-1                                   Hopper Wagon  2001      228.0
# 44  10018-1                                     Darth Maul  2001     1868.0
# 45  10019-1                    Rebel Blockade Runner - UCS  2001        NaN
# 46    100-2         4.5V Motor with Wheels (Large Version)  1966       27.0
# 47  10020-1  Santa Fe Super Chief, NOT the Limited Edition  2002        NaN
# 48  10020-2          Santa Fe Super Chief, Limited Edition  2002        NaN
# 49  10021-1                           U.S.S. Constellation  2003        NaN
#
#                  theme_name            parent_theme   id  is_licensed
# 0                    Castle                Legoland  411        False
# 1              Supplemental                    Town   50        False
# 2              Lion Knights                  Castle  186        False
# 3              Supplemental                   Space  126        False
# 4              Supplemental                   Space  126        False
# 5              Supplemental                   Space  126        False
# 6              Supplemental                   Space  126        False
# 7                    Castle                  Castle  186        False
# 8                  Building                Legoland  411        False
# 9                  Building                Legoland  411        False
# 10                 Building                Legoland  411        False
# 11                Basic Set                 Classic  365        False
# 12             Classic Town                    Town   50        False
# 13                 Building                Legoland  411        False
# 14                Basic Set                 Classic  365        False
# 15                Basic Set                 Classic  365        False
# 16                Basic Set                 Classic  365        False
# 17                Basic Set                 Classic  365        False
# 18                     Game                    Gear  501        False
# 19                Basic Set                 Classic  365        False
# 20                Basic Set                 Classic  365        False
# 21                Basic Set                 Classic  365        False
# 22                Basic Set                 Classic  365        False
# 23                Basic Set                 Classic  365        False
# 24                Basic Set  Universal Building Set  465        False
# 25                   Castle                  Castle  186        False
# 26                    Train                   Train  233        False
# 27                    Train                   Train  233        False
# 28              Bulk Bricks             Bulk Bricks  254        False
# 29              Bulk Bricks             Bulk Bricks  254        False
# 30              Bulk Bricks             Bulk Bricks  254        False
# 31              Bulk Bricks             Bulk Bricks  254        False
# 32              Bulk Bricks             Bulk Bricks  254        False
# 33              Bulk Bricks             Bulk Bricks  254        False
# 34              Bulk Bricks             Bulk Bricks  254        False
# 35                     4.5V                   Train  233        False
# 36              Bulk Bricks             Bulk Bricks  254        False
# 37              Bulk Bricks             Bulk Bricks  254        False
# 38              Bulk Bricks             Bulk Bricks  254        False
# 39             My Own Train                   Train  233        False
# 40             My Own Train                   Train  233        False
# 41             My Own Train                   Train  233        False
# 42             My Own Train                   Train  233        False
# 43             My Own Train                   Train  233        False
# 44                Star Wars               Star Wars  158         True
# 45  Star Wars Episode 4/5/6               Star Wars  158         True
# 46                     4.5V                   Train  233        False
# 47                       9V                   Train  233        False
# 48                       9V                   Train  233        False
# 49               Hobby Sets              Hobby Sets  404        False

# %% [markdown]
#     lets clean up the new DF merge_set
# - remove column "num_parts" --> useless
# - remove any NaNs in the "set_num" column --> very important any NaN means a set is duplicated or invalid.
# - check to see if there are any other NaNs in the other columns

# %%
# removing column num_parts
merged_data.drop(columns="num_parts",inplace=True)
merged_data.head()
# Out:
#   set_num                        name  year    theme_name parent_theme   id  \
# 0    00-1             Weetabix Castle  1970        Castle     Legoland  411
# 1  0011-2           Town Mini-Figures  1978  Supplemental         Town   50
# 2  0011-3  Castle 2 for 1 Bonus Offer  1987  Lion Knights       Castle  186
# 3  0012-1          Space Mini-Figures  1979  Supplemental        Space  126
# 4  0013-1          Space Mini-Figures  1979  Supplemental        Space  126
#
#    is_licensed
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False

# %%
merged_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11986 entries, 0 to 11985
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   set_num       11833 non-null  object
#  1   name          11833 non-null  object
#  2   year          11986 non-null  int64
#  3   theme_name    11833 non-null  object
#  4   parent_theme  11986 non-null  object
#  5   id            11986 non-null  int64
#  6   is_licensed   11986 non-null  bool
# dtypes: bool(1), int64(2), object(4)
# memory usage: 667.2+ KB

# %% [markdown]
# We see that there are a total of 11,986 rows in the entire Merged Dataset.<br> However, if you look at the columns section and the Non-Null count column we see that there are Null Values present.

# %%
merged_data[merged_data["set_num"].isna()].head(20)
# Out:
#       set_num name  year theme_name     parent_theme   id  is_licensed
# 11833     NaN  NaN  2017        NaN  Disney Princess  579         True
# 11834     NaN  NaN  2016        NaN  Disney Princess  579         True
# 11835     NaN  NaN  2016        NaN  Disney Princess  579         True
# 11836     NaN  NaN  2017        NaN     Super Heroes  482         True
# 11837     NaN  NaN  2017        NaN     Super Heroes  482         True
# 11838     NaN  NaN  2016        NaN        Minecraft  577         True
# 11839     NaN  NaN  2014        NaN     Super Heroes  482         True
# 11840     NaN  NaN  2013        NaN     Super Heroes  482         True
# 11841     NaN  NaN  2013        NaN     Super Heroes  482         True
# 11842     NaN  NaN  2013        NaN     Super Heroes  482         True
# 11843     NaN  NaN  2016        NaN     Super Heroes  482         True
# 11844     NaN  NaN  2014        NaN     Super Heroes  482         True
# 11845     NaN  NaN  2015        NaN        Minecraft  577         True
# 11846     NaN  NaN  2012        NaN        Minecraft  577         True
# 11847     NaN  NaN  2016        NaN        Minecraft  577         True
# 11848     NaN  NaN  2012        NaN     Super Heroes  482         True
# 11849     NaN  NaN  2014        NaN  Disney Princess  579         True
# 11850     NaN  NaN  2016        NaN     Super Heroes  482         True
# 11851     NaN  NaN  2013        NaN     Super Heroes  482         True
# 11852     NaN  NaN  2017        NaN     Super Heroes  482         True

# %% [markdown]
# Total Number of null values in each column:

# %%
merged_data.isna().sum()
# Out:
# set_num         153
# name            153
# year              0
# theme_name      153
# parent_theme      0
# id                0
# is_licensed       0
# dtype: int64

# %% [markdown]
# Removing Null Values:

# %%
#drop rows where set_num column has NaN values
merged_data.dropna(how="any",inplace=True)

# %%
merged_data.isna().sum()
# Out:
# set_num         0
# name            0
# year            0
# theme_name      0
# parent_theme    0
# id              0
# is_licensed     0
# dtype: int64

# %% [markdown]
# All the Null Values were removed.

# %%
merged_data.head()
# Out:
#   set_num                        name  year    theme_name parent_theme   id  \
# 0    00-1             Weetabix Castle  1970        Castle     Legoland  411
# 1  0011-2           Town Mini-Figures  1978  Supplemental         Town   50
# 2  0011-3  Castle 2 for 1 Bonus Offer  1987  Lion Knights       Castle  186
# 3  0012-1          Space Mini-Figures  1979  Supplemental        Space  126
# 4  0013-1          Space Mini-Figures  1979  Supplemental        Space  126
#
#    is_licensed
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False

# %%
licensed_true = merged_data[merged_data["is_licensed"]==True]
licensed_true.head()
# Out:
#     set_num                           name  year               theme_name  \
# 44  10018-1                     Darth Maul  2001                Star Wars
# 45  10019-1    Rebel Blockade Runner - UCS  2001  Star Wars Episode 4/5/6
# 54  10026-1        Naboo Starfighter - UCS  2002      Star Wars Episode 1
# 57  10030-1  Imperial Star Destroyer - UCS  2002  Star Wars Episode 4/5/6
# 95  10075-1         Spider-Man Action Pack  2002               Spider-Man
#
#     parent_theme   id  is_licensed
# 44     Star Wars  158         True
# 45     Star Wars  158         True
# 54     Star Wars  158         True
# 57     Star Wars  158         True
# 95  Super Heroes  482         True

# %%
licensed_count = licensed_true.groupby("is_licensed")
licensed_count.head()
# Out:
#     set_num                           name  year               theme_name  \
# 44  10018-1                     Darth Maul  2001                Star Wars
# 45  10019-1    Rebel Blockade Runner - UCS  2001  Star Wars Episode 4/5/6
# 54  10026-1        Naboo Starfighter - UCS  2002      Star Wars Episode 1
# 57  10030-1  Imperial Star Destroyer - UCS  2002  Star Wars Episode 4/5/6
# 95  10075-1         Spider-Man Action Pack  2002               Spider-Man
#
#     parent_theme   id  is_licensed
# 44     Star Wars  158         True
# 45     Star Wars  158         True
# 54     Star Wars  158         True
# 57     Star Wars  158         True
# 95  Super Heroes  482         True

# %%
licensed_count["parent_theme"].value_counts().head() #gives me the total number of sets that are star wars themed which is 609
# Out:
# is_licensed  parent_theme
# True         Star Wars                           609
#              Super Heroes                        242
#              Harry Potter                         67
#              The Hobbit and Lord of the Rings     40
#              Minecraft                            30
# Name: parent_theme, dtype: int64

# %%
licensed_true.info() # using the info method to see how many rows are there in the licensed_true DF, so i can use this to divide the star wars.
# rows in DF --> 1179
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1179 entries, 44 to 11822
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   set_num       1179 non-null   object
#  1   name          1179 non-null   object
#  2   year          1179 non-null   int64
#  3   theme_name    1179 non-null   object
#  4   parent_theme  1179 non-null   object
#  5   id            1179 non-null   int64
#  6   is_licensed   1179 non-null   bool
# dtypes: bool(1), int64(2), object(4)
# memory usage: 65.6+ KB

# %%
the_force =  round((609/1179)*100) # using this equation to figure out the percentage of star wars sets out of all time released sets that were licensed
print(the_force)
# Out:
# 52

# %% [markdown]
# ### __Q1 Answer:__<font color="yellow"> 52 percent</font>
# ***

# %% [markdown]
# ### Q2: __In which year was star wars not the most popular licensed theme(in terms of number of sets released that year)__ <br>

# %%
licensed_true.head()
# Out:
#     set_num                           name  year               theme_name  \
# 44  10018-1                     Darth Maul  2001                Star Wars
# 45  10019-1    Rebel Blockade Runner - UCS  2001  Star Wars Episode 4/5/6
# 54  10026-1        Naboo Starfighter - UCS  2002      Star Wars Episode 1
# 57  10030-1  Imperial Star Destroyer - UCS  2002  Star Wars Episode 4/5/6
# 95  10075-1         Spider-Man Action Pack  2002               Spider-Man
#
#     parent_theme   id  is_licensed
# 44     Star Wars  158         True
# 45     Star Wars  158         True
# 54     Star Wars  158         True
# 57     Star Wars  158         True
# 95  Super Heroes  482         True

# %%
licensed_true[licensed_true["year"]==1999]
# Out:
#      set_num                  name  year               theme_name  \
# 7607  7101-1       Lightsaber Duel  1999      Star Wars Episode 1
# 7728  7110-1           Landspeeder  1999  Star Wars Episode 4/5/6
# 7730  7111-1         Droid Fighter  1999      Star Wars Episode 1
# 7752  7121-1           Naboo Swamp  1999      Star Wars Episode 1
# 7799  7128-1         Speeder Bikes  1999  Star Wars Episode 4/5/6
# 7804  7130-1           Snowspeeder  1999  Star Wars Episode 4/5/6
# 7815  7131-1     Anakin's Podracer  1999      Star Wars Episode 1
# 7836  7140-1        X-wing Fighter  1999  Star Wars Episode 4/5/6
# 7837  7141-1         Naboo Fighter  1999      Star Wars Episode 1
# 7845  7150-1  TIE Fighter & Y-wing  1999  Star Wars Episode 4/5/6
# 7847  7151-1      Sith Infiltrator  1999      Star Wars Episode 1
# 7856  7161-1            Gungan Sub  1999      Star Wars Episode 1
# 7866  7171-1      Mos Espa Podrace  1999      Star Wars Episode 1
#
#      parent_theme   id  is_licensed
# 7607    Star Wars  158         True
# 7728    Star Wars  158         True
# 7730    Star Wars  158         True
# 7752    Star Wars  158         True
# 7799    Star Wars  158         True
# 7804    Star Wars  158         True
# 7815    Star Wars  158         True
# 7836    Star Wars  158         True
# 7837    Star Wars  158         True
# 7845    Star Wars  158         True
# 7847    Star Wars  158         True
# 7856    Star Wars  158         True
# 7866    Star Wars  158         True

# %%
licensed_true.groupby("year").count()["parent_theme"]
# Out:
# year
# 1999     13
# 2000     31
# 2001     25
# 2002     50
# 2003     40
# 2004     40
# 2005     35
# 2006     24
# 2007     21
# 2008     43
# 2009     48
# 2010     63
# 2011     81
# 2012    109
# 2013     86
# 2014     99
# 2015    107
# 2016    121
# 2017    143
# Name: parent_theme, dtype: int64

# %%
not_popular = licensed_true.groupby("year")

# %%
not_popular2 = not_popular["parent_theme"].value_counts()

# %%
not_popular2.head(50)
# Out:
# year  parent_theme
# 1999  Star Wars                           13
# 2000  Star Wars                           26
#       Disney's Mickey Mouse                5
# 2001  Star Wars                           14
#       Harry Potter                        11
# 2002  Star Wars                           28
#       Harry Potter                        19
#       Super Heroes                         3
# 2003  Star Wars                           32
#       Super Heroes                         5
#       Harry Potter                         3
# 2004  Star Wars                           20
#       Harry Potter                        14
#       Super Heroes                         6
# 2005  Star Wars                           28
#       Harry Potter                         5
#       Disney's Mickey Mouse                1
#       Super Heroes                         1
# 2006  Star Wars                           11
#       Super Heroes                         8
#       SpongeBob SquarePants                3
#       Avatar                               2
# 2007  Star Wars                           16
#       SpongeBob SquarePants                2
#       Super Heroes                         2
#       Harry Potter                         1
# 2008  Star Wars                           23
#       Indiana Jones                       12
#       Super Heroes                         5
#       SpongeBob SquarePants                3
# 2009  Star Wars                           39
#       Indiana Jones                        7
#       SpongeBob SquarePants                2
# 2010  Star Wars                           30
#       Toy Story                           15
#       Ben 10                               6
#       Harry Potter                         6
#       Prince of Persia                     6
# 2011  Star Wars                           32
#       Cars                                18
#       Pirates of the Caribbean            16
#       Harry Potter                         8
#       Super Heroes                         5
#       SpongeBob SquarePants                2
# 2012  Star Wars                           43
#       Super Heroes                        32
#       The Hobbit and Lord of the Rings    20
#       Cars                                 9
#       SpongeBob SquarePants                2
#       Teenage Mutant Ninja Turtles         2
# Name: parent_theme, dtype: int64

# %%
not_popular2.tail(30)
# Out:
# year  parent_theme
# 2013  The Hobbit and Lord of the Rings    13
#       Teenage Mutant Ninja Turtles         9
#       The Lone Ranger                      8
#       Minecraft                            2
# 2014  Star Wars                           45
#       Super Heroes                        23
#       Teenage Mutant Ninja Turtles        10
#       Disney Princess                      8
#       Minecraft                            7
#       The Hobbit and Lord of the Rings     6
# 2015  Star Wars                           58
#       Super Heroes                        28
#       Jurassic World                       7
#       Scooby-Doo                           5
#       Disney Princess                      4
#       Minecraft                            4
#       The Hobbit and Lord of the Rings     1
# 2016  Star Wars                           61
#       Super Heroes                        33
#       Disney Princess                     11
#       Minecraft                            7
#       Angry Birds                          6
#       Disney                               1
#       Ghostbusters                         1
#       Scooby-Doo                           1
# 2017  Super Heroes                        72
#       Star Wars                           55
#       Minecraft                            9
#       Disney Princess                      6
#       Pirates of the Caribbean             1
# Name: parent_theme, dtype: int64

# %% [markdown]
# ### __Q2 Answer:__<font color="yellow"> year 2017</font>

# %% [markdown]
# <font size="7">__Another way to solve the problem above__</font>

# %%
popular_set = licensed_true.sort_values("year")

popular_set2 = popular_set.groupby(["year","parent_theme"]).sum().reset_index()
popular_set2.head()
# Out:
#    year           parent_theme    id  is_licensed
# 0  1999              Star Wars  2054           13
# 1  2000  Disney's Mickey Mouse  1940            5
# 2  2000              Star Wars  4108           26
# 3  2001           Harry Potter  2706           11
# 4  2001              Star Wars  2212           14

# %%
popular_max = popular_set2.sort_values(by="is_licensed",ascending=False).drop_duplicates(["year"])
popular_max.head(50)
# Out:
#     year  parent_theme     id  is_licensed
# 82  2017  Super Heroes  34704           72
# 76  2016     Star Wars   9638           61
# 67  2015     Star Wars   9164           58
# 59  2014     Star Wars   7110           45
# 47  2012     Star Wars   6794           43
# 32  2009     Star Wars   6162           39
# 52  2013     Star Wars   5530           35
# 9   2003     Star Wars   5056           32
# 42  2011     Star Wars   5056           32
# 36  2010     Star Wars   4740           30
# 16  2005     Star Wars   4424           28
# 6   2002     Star Wars   4424           28
# 2   2000     Star Wars   4108           26
# 28  2008     Star Wars   3634           23
# 12  2004     Star Wars   3160           20
# 24  2007     Star Wars   2528           16
# 4   2001     Star Wars   2212           14
# 0   1999     Star Wars   2054           13
# 20  2006     Star Wars   1738           11

# %%
popular_max.sort_values("year",inplace=True)
popular_max.head(20)
# Out:
#     year  parent_theme     id  is_licensed
# 0   1999     Star Wars   2054           13
# 2   2000     Star Wars   4108           26
# 4   2001     Star Wars   2212           14
# 6   2002     Star Wars   4424           28
# 9   2003     Star Wars   5056           32
# 12  2004     Star Wars   3160           20
# 16  2005     Star Wars   4424           28
# 20  2006     Star Wars   1738           11
# 24  2007     Star Wars   2528           16
# 28  2008     Star Wars   3634           23
# 32  2009     Star Wars   6162           39
# 36  2010     Star Wars   4740           30
# 42  2011     Star Wars   5056           32
# 47  2012     Star Wars   6794           43
# 52  2013     Star Wars   5530           35
# 59  2014     Star Wars   7110           45
# 67  2015     Star Wars   9164           58
# 76  2016     Star Wars   9638           61
# 82  2017  Super Heroes  34704           72

# %% [markdown]
# ***

# %% [markdown]
# ### __Additional Question: Break down number of sets by Year__

# %%
merged_data["year"].unique()
# Out:
# array([1970, 1978, 1987, 1979, 1976, 1965, 1985, 1968, 1999, 1967, 1969,
#        2001, 1966, 2003, 2002, 2004, 2006, 2005, 2010, 2007, 2008, 2009,
#        2011, 2012, 2013, 2014, 2015, 2016, 2017, 1977, 1983, 1986, 1984,
#        1973, 1981, 2000, 1980, 1982, 1988, 1997, 1998, 1971, 1955, 1956,
#        1957, 1958, 1974, 1972, 1975, 1992, 1991, 1989, 1990, 1993, 1994,
#        1996, 1995, 1959, 1962, 1961, 1960, 1963, 1964, 1950, 1953, 1954],
#       dtype=int64)

# %%
merged_data.head()
# Out:
#   set_num                        name  year    theme_name parent_theme   id  \
# 0    00-1             Weetabix Castle  1970        Castle     Legoland  411
# 1  0011-2           Town Mini-Figures  1978  Supplemental         Town   50
# 2  0011-3  Castle 2 for 1 Bonus Offer  1987  Lion Knights       Castle  186
# 3  0012-1          Space Mini-Figures  1979  Supplemental        Space  126
# 4  0013-1          Space Mini-Figures  1979  Supplemental        Space  126
#
#    is_licensed
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False

# %%
merged_data.groupby("year").count().sort_values("parent_theme",ascending=False).head(66)
# Out:
#       set_num  name  theme_name  parent_theme   id  is_licensed
# year
# 2014      715   715         715           715  715          715
# 2015      670   670         670           670  670          670
# 2012      615   615         615           615  615          615
# 2016      608   608         608           608  608          608
# 2013      593   593         593           593  593          593
# ...       ...   ...         ...           ...  ...          ...
# 1965       10    10          10            10   10           10
# 1950        7     7           7             7    7            7
# 1959        4     4           4             4    4            4
# 1953        4     4           4             4    4            4
# 1960        3     3           3             3    3            3
#
# [66 rows x 6 columns]

# %%
sets_per_year = merged_data.groupby("year").count().reset_index()
sets_per_year
# Out:
#     year  set_num  name  theme_name  parent_theme   id  is_licensed
# 0   1950        7     7           7             7    7            7
# 1   1953        4     4           4             4    4            4
# 2   1954       14    14          14            14   14           14
# 3   1955       28    28          28            28   28           28
# 4   1956       12    12          12            12   12           12
# ..   ...      ...   ...         ...           ...  ...          ...
# 61  2013      593   593         593           593  593          593
# 62  2014      715   715         715           715  715          715
# 63  2015      670   670         670           670  670          670
# 64  2016      608   608         608           608  608          608
# 65  2017      438   438         438           438  438          438
#
# [66 rows x 7 columns]

# %%
sets_year = sets_per_year[["year","parent_theme"]].sort_values("parent_theme",ascending=False).copy()

# %%
sets_year.rename(columns={"parent_theme":"sets"},inplace=True)

# %%
sets_year.head(100)
# Out:
#     year  sets
# 62  2014   715
# 63  2015   670
# 60  2012   615
# 64  2016   608
# 61  2013   593
# ..   ...   ...
# 13  1965    10
# 0   1950     7
# 7   1959     4
# 1   1953     4
# 8   1960     3
#
# [66 rows x 2 columns]

# %% [markdown]
# Answer: Year 2014 had the most sets released which was a total of 715.
